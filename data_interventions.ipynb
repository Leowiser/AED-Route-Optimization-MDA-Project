# %% [markdown]
# Find data interventions in Leuven

# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
# look at all intervention datasets 
# bxl, bxl2 did not have any data in Leuven
intervention1 = pd.read_parquet("Data/interventions1.parquet.gzip")

# %%
print(intervention1)
# Out:
#          Mission ID                 Service Name  PostalCode permanence  \
# 0       10221520001     HA UR MECH AZ St Maarten                 2800.0
# 1       10221520002               BA KAPE AMBUCE                 2950.0
# 2       10221520002       HA UR ANTW Stuivenberg                 2060.0
# 3       10221520004  BA ANTW [Borgerhout] AMBUCE                 2140.0
# 4       10221520005               BA WIJN AMBUCE                 2110.0
# ...             ...                          ...                    ...
# 200622  50221920082      FH PDS BEAU Hainaut Est                 6500.0
# 200623  50221920083            BH LOUV AS Grande                 7110.0
# 200624  50221920084  BH GERP SAPG Poste Loverval                 6280.0
# 200625  50221920085   FH PDS BINC Hainaut Centre                 7130.0
# 200626  50221920085        HH UR LOUV CHU Tivoli                 7100.0
#
#                         CityName permanence       StreetName permanence  \
# 0                       Mechelen (Mechelen)              Liersesteenweg
# 1                       Kapellen (Kapellen)             Essenhoutstraat
# 2                     Antwerpen (Antwerpen)      Lange Beeldekensstraat
# 3                    Antwerpen (Borgerhout)               Gijselsstraat
# 4                       Wijnegem (Wijnegem)               Bijkhoevelaan
# ...                                     ...                         ...
# 200622                  Beaumont (Beaumont)           Chauss√©e de Mons
# 200623  La Louvi√®re (Str√©py-Bracquegnies)             Rue de Nivelles
# 200624                 Gerpinnes (Loverval)  Chauss√©e de Philippeville
# 200625                      Binche (Binche)       Rue de la P√©pini√®re
# 200626          La Louvi√®re (La Louvi√®re)            Avenue Max Buset
#
#        HouseNumber permanence  Latitude permanence  Longitude permanence  \
# 0                        None            51.051020              4.478030
# 1                        None            51.312075              4.424398
# 2                        None            51.222490              4.436290
# 3                        None            51.215620              4.443920
# 4                        None            51.233550              4.493180
# ...                       ...                  ...                   ...
# 200622                   None            50.241870              4.234680
# 200623                   None            50.469758              4.128008
# 200624                   None            50.373360              4.467450
# 200625                    57A            50.415230                   NaN
# 200626                   None            50.477800              4.205120
#
#        Permanence short name Permanence long name  ... Unavailable time  \
# 0                  AAMECH01A        ZW MECHELEN 1  ...              NaN
# 1                  AAKAPE01A        ZW KAPELLEN 1  ...              NaN
# 2                  UAANTW01A      MUG ANTWERPEN 1  ...              NaN
# 3                  AAANTW07A       ZW ANTWERPEN 7  ...              NaN
# 4                  AAWIJN01A        ZW WIJNEGEM 1  ...              NaN
# ...                      ...                  ...  ...              ...
# 200622             AHBEAU01A        ZS BEAUMONT 1  ...              NaN
# 200623             AHLOUV03A         AMB STREPY 1  ...              NaN
# 200624             AHGERP01A       AMB LOVERVAL 1  ...              NaN
# 200625             AHBINC01A          ZS BINCHE 1  ...              NaN
# 200626             UHLOUV02A     SMUR LOUV TIVOLI  ...              NaN
#
#           Name destination hospital PostalCode destination hospital  \
# 0                              None                            None
# 1            HA UR ANTW Jan Palfijn                            None
# 2                              None                            None
# 3                              None                            None
# 4            HA UR ANTW Jan Palfijn                            None
# ...                             ...                             ...
# 200622  HH UR MONI CHU Andre Vesale                            None
# 200623        HH UR LOUV CHU Tivoli                            None
# 200624      HH EX LOVE IMTR Brul√©s                            None
# 200625      HH UR LOUV CHU Jolimont                            None
# 200626                         None                            None
#
#           CityName destination hospital StreetName destination hospital  \
# 0                                  None                            None
# 1                   Antwerpen (Merksem)                Lange Bremstraat
# 2                                  None                            None
# 3                                  None                            None
# 4                   Antwerpen (Merksem)                Lange Bremstraat
# ...                                 ...                             ...
# 200622              Montigny-le-Tilleul                   Rue de Goz√©e
# 200623      La Louvi√®re (La Louvi√®re)                Avenue Max Buset
# 200624             Gerpinnes (Loverval)                  Rue de Villers
# 200625  La Louvi√®re (Haine-Saint-Paul)                      Rue Ferrer
# 200626                             None                            None
#
#        HouseNumber destination hospital Calculated travelTime destinatio  \
# 0                                  None                              NaN
# 1                                  None                            678.0
# 2                                  None                              NaN
# 3                                  None                              NaN
# 4                                  None                            530.0
# ...                                 ...                              ...
# 200622                             None                              NaN
# 200623                             None                              NaN
# 200624                             None                              NaN
# 200625                             None                              NaN
# 200626                             None                              NaN
#
#         Calculated Distance destination  Number of transported persons  \
# 0                                   NaN                            NaN
# 1                               11743.0                            1.0
# 2                                   NaN                            NaN
# 3                                   NaN                            NaN
# 4                                5468.0                            1.0
# ...                                 ...                            ...
# 200622                              NaN                            1.0
# 200623                              NaN                            1.0
# 200624                              NaN                            1.0
# 200625                              NaN                            1.0
# 200626                              NaN                            NaN
#
#               Abandon reason
# 0       Verzorgd ter plaatse
# 1                       None
# 2                       None
# 3             Zonder patient
# 4                       None
# ...                      ...
# 200622                  None
# 200623                  None
# 200624                  None
# 200625                  None
# 200626                  None
#
# [200627 rows x 46 columns]

# %%
# print headings of data set
intervention1.head()
# Out:
#     Mission ID                 Service Name  PostalCode permanence  \
# 0  10221520001     HA UR MECH AZ St Maarten                 2800.0
# 1  10221520002               BA KAPE AMBUCE                 2950.0
# 2  10221520002       HA UR ANTW Stuivenberg                 2060.0
# 3  10221520004  BA ANTW [Borgerhout] AMBUCE                 2140.0
# 4  10221520005               BA WIJN AMBUCE                 2110.0
#
#       CityName permanence   StreetName permanence HouseNumber permanence  \
# 0     Mechelen (Mechelen)          Liersesteenweg                   None
# 1     Kapellen (Kapellen)         Essenhoutstraat                   None
# 2   Antwerpen (Antwerpen)  Lange Beeldekensstraat                   None
# 3  Antwerpen (Borgerhout)           Gijselsstraat                   None
# 4     Wijnegem (Wijnegem)           Bijkhoevelaan                   None
#
#    Latitude permanence  Longitude permanence Permanence short name  \
# 0            51.051020              4.478030             AAMECH01A
# 1            51.312075              4.424398             AAKAPE01A
# 2            51.222490              4.436290             UAANTW01A
# 3            51.215620              4.443920             AAANTW07A
# 4            51.233550              4.493180             AAWIJN01A
#
#   Permanence long name  ... Unavailable time Name destination hospital  \
# 0        ZW MECHELEN 1  ...              NaN                      None
# 1        ZW KAPELLEN 1  ...              NaN    HA UR ANTW Jan Palfijn
# 2      MUG ANTWERPEN 1  ...              NaN                      None
# 3       ZW ANTWERPEN 7  ...              NaN                      None
# 4        ZW WIJNEGEM 1  ...              NaN    HA UR ANTW Jan Palfijn
#
#   PostalCode destination hospital CityName destination hospital  \
# 0                            None                          None
# 1                            None           Antwerpen (Merksem)
# 2                            None                          None
# 3                            None                          None
# 4                            None           Antwerpen (Merksem)
#
#   StreetName destination hospital HouseNumber destination hospital  \
# 0                            None                             None
# 1                Lange Bremstraat                             None
# 2                            None                             None
# 3                            None                             None
# 4                Lange Bremstraat                             None
#
#   Calculated travelTime destinatio  Calculated Distance destination  \
# 0                              NaN                              NaN
# 1                            678.0                          11743.0
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                            530.0                           5468.0
#
#    Number of transported persons        Abandon reason
# 0                            NaN  Verzorgd ter plaatse
# 1                            1.0                  None
# 2                            NaN                  None
# 3                            NaN        Zonder patient
# 4                            1.0                  None
#
# [5 rows x 46 columns]

# %%
# inspect the dataset
print(intervention1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200627 entries, 0 to 200626
# Data columns (total 46 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Mission ID                        200627 non-null  int64
#  1   Service Name                      200493 non-null  object
#  2   PostalCode permanence             200266 non-null  float64
#  3   CityName permanence               200265 non-null  object
#  4   StreetName permanence             200492 non-null  object
#  5   HouseNumber permanence            8433 non-null    object
#  6   Latitude permanence               169009 non-null  float64
#  7   Longitude permanence              198104 non-null  float64
#  8   Permanence short name             200619 non-null  object
#  9   Permanence long name              200619 non-null  object
#  10  Vector type                       200627 non-null  object
#  11  EventType Firstcall               200626 non-null  object
#  12  EventLevel Firstcall              192769 non-null  object
#  13  EventType Trip                    200625 non-null  object
#  14  EventLevel Trip                   197044 non-null  object
#  15  PostalCode intervention           271 non-null     object
#  16  CityName intervention             200601 non-null  object
#  17  Latitude intervention             170404 non-null  float64
#  18  Longitude intervention            200163 non-null  float64
#  19  Province intervention             200627 non-null  object
#  20  T0                                200627 non-null  object
#  21  T1                                200627 non-null  object
#  22  T1confirmed                       158621 non-null  object
#  23  T2                                158530 non-null  object
#  24  T3                                153687 non-null  object
#  25  T4                                124536 non-null  object
#  26  T5                                117599 non-null  object
#  27  T6                                126483 non-null  object
#  28  T7                                147585 non-null  object
#  29  T9                                2675 non-null    object
#  30  Intervention time (T1Reported)    184064 non-null  float64
#  31  Intervention time (T1Confirmed)   178453 non-null  float64
#  32  Waiting time                      184064 non-null  float64
#  33  Intervention duration             151879 non-null  float64
#  34  Departure time (T1Reported)       189735 non-null  float64
#  35  Departure time (T1Confirmed)      183785 non-null  float64
#  36  Unavailable time                  3566 non-null    float64
#  37  Name destination hospital         150735 non-null  object
#  38  PostalCode destination hospital   0 non-null       object
#  39  CityName destination hospital     150778 non-null  object
#  40  StreetName destination hospital   150777 non-null  object
#  41  HouseNumber destination hospital  307 non-null     object
#  42  Calculated travelTime destinatio  125585 non-null  float64
#  43  Calculated Distance destination   125585 non-null  float64
#  44  Number of transported persons     134321 non-null  float64
#  45  Abandon reason                    22838 non-null   object
# dtypes: float64(15), int64(1), object(30)
# memory usage: 70.4+ MB
# None

# %%
# create a list of Leuven and its submunicipalities
leuven_submunicipalities = ['Leuven (Heverlee)', 'Leuven (Kessel-Lo)', 'Leuven (Wilsele)', 'Leuven (Wijgmaal)', 'Leuven (Korbeek-Lo)', 'Leuven (Haasrode)', 'Leuven (Leuven)', 'LEUVEN', 'Leuven', 'HAASRODE', 'HEVERLEE', 'KESSEL-LO', 'WILSELE', 'WIJGMAAL', 'KORBEEK-LO']

# filter the DataFrame using boolean indexing
filtered_interventions1 = intervention1[intervention1['CityName intervention'].isin(leuven_submunicipalities)]

# %%
filtered_interventions1
# Out:
#          Mission ID                      Service Name  PostalCode permanence  \
# 4278    10221620267                   BA KONT ACL ACK                 2550.0
# 9446    10221740250                   BA KONT ACL ACK                 2550.0
# 66061   10223170184                   BA KONT ACL ACK                 2550.0
# 116912  10230790206                   BA KONT ACL ACK                 2550.0
# 142163  21221820005  HV UR LEUV UZ Gasthuisberg | MUG                 3001.0
# 142164  21221820006  HV UR LEUV UZ Gasthuisberg | PIT                 3001.0
# 142167  21231420002                BV LEUV Rode Kruis                 3000.0
#
#        CityName permanence   StreetName permanence HouseNumber permanence  \
# 4278     Kontich (Kontich)        Duffelsesteenweg                   None
# 9446     Kontich (Kontich)        Duffelsesteenweg                   None
# 66061    Kontich (Kontich)        Duffelsesteenweg                   None
# 116912   Kontich (Kontich)        Duffelsesteenweg                   None
# 142163   Leuven (Heverlee)              Herestraat                   None
# 142164   Leuven (Heverlee)              Herestraat                   None
# 142167     Leuven (Leuven)  Onze-Lieve-Vrouwstraat                   None
#
#         Latitude permanence  Longitude permanence Permanence short name  \
# 4278               51.13029               4.44949             AAKONT02A
# 9446               51.13029               4.44949             AAKONT02A
# 66061              51.13029               4.44949             AAKONT02A
# 116912             51.13029               4.44949             AAKONT02A
# 142163             50.87616               4.67061             UVLEUV01A
# 142164             50.87615               4.67073             PVLEUV01A
# 142167                  NaN             469.54800             AVLEUV01B
#
#             Permanence long name  ... Unavailable time  \
# 4278    ZW KONTICH 2 COLLOCATIES  ...              NaN
# 9446    ZW KONTICH 2 COLLOCATIES  ...              NaN
# 66061   ZW KONTICH 2 COLLOCATIES  ...              NaN
# 116912  ZW KONTICH 2 COLLOCATIES  ...              NaN
# 142163              MUG LEUVEN 1  ...              NaN
# 142164              PIT LEUVEN 1  ...              NaN
# 142167            ZW LEUVEN 1 RK  ...              NaN
#
#                 Name destination hospital PostalCode destination hospital  \
# 4278    HA PS MORT PC Multiversum Amadeus                            None
# 9446                       HA PS GEEL OPZ                            None
# 66061                      HA PS GEEL OPZ                            None
# 116912                     HA PS GEEL OPZ                            None
# 142163                               None                            None
# 142164         HV UR LEUV UZ Gasthuisberg                            None
# 142167          HV UR LEUV RZ Heilig Hart                            None
#
#        CityName destination hospital StreetName destination hospital  \
# 4278               Mortsel (Mortsel)                    Deurnestraat
# 9446                     Geel (Geel)                   Dr.-Sanodreef
# 66061                    Geel (Geel)                   Dr.-Sanodreef
# 116912                   Geel (Geel)                   Dr.-Sanodreef
# 142163                          None                            None
# 142164             Leuven (Heverlee)                      Herestraat
# 142167               Leuven (Leuven)                    Naamsestraat
#
#        HouseNumber destination hospital Calculated travelTime destinatio  \
# 4278                               None                              NaN
# 9446                               None                              NaN
# 66061                              None                              NaN
# 116912                             None                              NaN
# 142163                             None                              NaN
# 142164                             None                              NaN
# 142167                             None                            199.0
#
#         Calculated Distance destination  Number of transported persons  \
# 4278                                NaN                            NaN
# 9446                                NaN                            NaN
# 66061                               NaN                            NaN
# 116912                              NaN                            1.0
# 142163                              NaN                            NaN
# 142164                              NaN                            1.0
# 142167                              0.0                            NaN
#
#        Abandon reason
# 4278             None
# 9446             None
# 66061            None
# 116912           None
# 142163           None
# 142164           None
# 142167           None
#
# [7 rows x 46 columns]

# %%
filtered_interventions1['T1']
# Out:
# 4278      11JUN22:16:29:30
# 9446      23JUN22:13:45:16
# 66061     13NOV22:12:17:29
# 116912    20MAR23:14:54:21
# 142163    01JUL22:14:51:38
# 142164    01JUL22:14:53:23
# 142167    22MAY23:11:38:09
# Name: T1, dtype: object

# %%
filtered_interventions1['T3']
# Out:
# 4278      2022-06-11 17:01:51.076
# 9446      2022-06-23 14:25:42.016
# 66061     2022-11-13 13:14:18.592
# 116912    2023-03-20 15:27:56.715
# 142163                       None
# 142164                       None
# 142167                       None
# Name: T3, dtype: object

# %%
# can only use the ones that have T1 and T3, filer out the rest 
filtered_interventions = filtered_interventions1[filtered_interventions1['T1'].notna()]
filtered_interventions = filtered_interventions1[filtered_interventions1['T3'].notna()]
filtered_interventions
# Out:
#          Mission ID     Service Name  PostalCode permanence  \
# 4278    10221620267  BA KONT ACL ACK                 2550.0
# 9446    10221740250  BA KONT ACL ACK                 2550.0
# 66061   10223170184  BA KONT ACL ACK                 2550.0
# 116912  10230790206  BA KONT ACL ACK                 2550.0
#
#        CityName permanence StreetName permanence HouseNumber permanence  \
# 4278     Kontich (Kontich)      Duffelsesteenweg                   None
# 9446     Kontich (Kontich)      Duffelsesteenweg                   None
# 66061    Kontich (Kontich)      Duffelsesteenweg                   None
# 116912   Kontich (Kontich)      Duffelsesteenweg                   None
#
#         Latitude permanence  Longitude permanence Permanence short name  \
# 4278               51.13029               4.44949             AAKONT02A
# 9446               51.13029               4.44949             AAKONT02A
# 66061              51.13029               4.44949             AAKONT02A
# 116912             51.13029               4.44949             AAKONT02A
#
#             Permanence long name  ... Unavailable time  \
# 4278    ZW KONTICH 2 COLLOCATIES  ...              NaN
# 9446    ZW KONTICH 2 COLLOCATIES  ...              NaN
# 66061   ZW KONTICH 2 COLLOCATIES  ...              NaN
# 116912  ZW KONTICH 2 COLLOCATIES  ...              NaN
#
#                 Name destination hospital PostalCode destination hospital  \
# 4278    HA PS MORT PC Multiversum Amadeus                            None
# 9446                       HA PS GEEL OPZ                            None
# 66061                      HA PS GEEL OPZ                            None
# 116912                     HA PS GEEL OPZ                            None
#
#        CityName destination hospital StreetName destination hospital  \
# 4278               Mortsel (Mortsel)                    Deurnestraat
# 9446                     Geel (Geel)                   Dr.-Sanodreef
# 66061                    Geel (Geel)                   Dr.-Sanodreef
# 116912                   Geel (Geel)                   Dr.-Sanodreef
#
#        HouseNumber destination hospital Calculated travelTime destinatio  \
# 4278                               None                              NaN
# 9446                               None                              NaN
# 66061                              None                              NaN
# 116912                             None                              NaN
#
#         Calculated Distance destination  Number of transported persons  \
# 4278                                NaN                            NaN
# 9446                                NaN                            NaN
# 66061                               NaN                            NaN
# 116912                              NaN                            1.0
#
#        Abandon reason
# 4278             None
# 9446             None
# 66061            None
# 116912           None
#
# [4 rows x 46 columns]

# %%
# filter the data so only the cardiac arrest cases are left 
filtered_interventions1['EventType Trip']
# Out:
# 4278      P097 - Collocation (planned)
# 9446      P097 - Collocation (planned)
# 66061     P097 - Collocation (planned)
# 116912    P097 - Collocation (planned)
# 142163                 P090 - Test MED
# 142164                 P090 - Test MED
# 142167                 P090 - Test MED
# Name: EventType Trip, dtype: object

# %% [markdown]
# None of these contained any cardiac arrests -> drop this dataset

# %%
# check the rest of the datasets 
intervention_data_2 = pd.read_parquet("Data/interventions2.parquet.gzip")
intervention_data_3 = pd.read_parquet("Data/interventions3.parquet.gzip")

# %%
# print headings of data set
intervention_data_2.head()
# Out:
#     Mission ID                       Service Name  PostalCode permanence  \
# 0  50221920087       FH PDS COMI Wallonie Picarde                 7784.0
# 1  50221920088       FH PDS TOUR Wallonie Picarde                 7500.0
# 2  50221920089         FH PDS LOUV Hainaut Centre                 7100.0
# 3  50221920090  FW HVP HEUV [Nieuwkerke] Westhoek                 8950.0
# 4  50221920092                BH SGHI Croix Rouge                 7331.0
#
#            CityName permanence      StreetName permanence  \
# 0  Comines-Warneton (Warneton)          Chauss√©e d'Ypres
# 1            Tournai (Tournai)            Avenue de Maire
# 2  La Louvi√®re (La Louvi√®re)  Boulevard du Roi Baudouin
# 3      Heuvelland (Nieuwkerke)            Dranouterstraat
# 4     Saint-Ghislain (Baudour)             Rue Louis Caty
#
#   HouseNumber permanence  Latitude permanence  Longitude permanence  \
# 0                   None             50.76034              2.940230
# 1                   None             50.61652              3.375120
# 2                   None             50.46800              4.192170
# 3                   None             50.74621              2.822500
# 4                   None             50.46963              3.842559
#
#   Permanence short name Permanence long name  ... Unavailable time  \
# 0             AHCOMI01A         ZS COMINES 1  ...              NaN
# 1             AHTOUR01A         ZS TOURNAI 1  ...              NaN
# 2             AHLOUV02A   ZS LA LOUVIERE PIM  ...              NaN
# 3             AWHEUV01A        ZW NIEUWKERKE  ...            604.0
# 4             AHSGHI01A  CR SAINT-GHISLAIN 1  ...              NaN
#
#                       Name destination hospital  \
# 0                                HH UR MOUS CHM
# 1          HH UR TOUR CH Wallonie Picarde Union
# 2                       HH UR LOUV CHU Jolimont
# 3                   HFR EX ARME CH Armenti√®res
# 4  HH UR BOUS CH Epicura (H√¥pital Grand Hornu)
#
#   PostalCode destination hospital    CityName destination hospital  \
# 0                            None              Mouscron (Mouscron)
# 1                            None                Tournai (Tournai)
# 2                            None  La Louvi√®re (Haine-Saint-Paul)
# 3                            None                 FRA-Armenti√®res
# 4                            None                   Boussu (Hornu)
#
#   StreetName destination hospital HouseNumber destination hospital  \
# 0               Avenue de F√©camp                             None
# 1                  Rue des Sports                             None
# 2                      Rue Ferrer                             None
# 3                 Rue Sadi Carnot                             None
# 4                 Rue du Commerce                             None
#
#   Calculated travelTime destinatio  Calculated Distance destination  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    Number of transported persons Abandon reason
# 0                            1.0           None
# 1                            1.0           None
# 2                            1.0           None
# 3                            NaN           None
# 4                            1.0           None
#
# [5 rows x 46 columns]

# %%
# print headings of data set
intervention_data_3.head()
# Out:
#     Mission ID                        Service Name  PostalCode permanence  \
# 0  60230050009                 BG LIEG Croix Rouge                 4000.0
# 1  60230050010  FG PDS PEPI Vesdre Ho√´gne Plateau                 4860.0
# 2  60230050012                    BG LIEG Courtois                 4030.0
# 3  60230050013             FG PDS ANS_ Li√®ge IILE                 4000.0
# 4  60230050014             FG PDS FLEM Li√®ge IILE                 4400.0
#
#            CityName permanence  StreetName permanence HouseNumber permanence  \
# 0              Li√®ge (Li√®ge)            Rue Darchis                   None
# 1        Pepinster (Pepinster)         Rue Jean Simon                   None
# 2          Li√®ge (Grivegn√©e)            Rue Belvaux                   None
# 3               li√®ge (glain)  p537;rue jean jaur√®s                   None
# 4  Fl√©malle (Fl√©malle-Haute)            Grand'Route                   None
#
#    Latitude permanence  Longitude permanence Permanence short name  \
# 0            50.637357              5.566551             AGLIEG05A
# 1            50.565940              5.802540             AGPEPI01A
# 2            50.619828              5.602470             AGLIEG02A
# 3            50.652240              5.526410             AGANS_01A
# 4            50.599360              5.472130             AGFLEM01A
#
#   Permanence long name  ... Unavailable time  Name destination hospital  \
# 0           CR LIEGE 2  ...              NaN                       None
# 1         ZS.PEPINST 1  ...              NaN    HG UR VERV CHR Tourelle
# 2            PR.COURT2  ...              NaN   HG UR LIEG CHC Montlegia
# 3             ZS ANS 1  ...              NaN                       None
# 4        ZS FLEMALLE 1  ...              NaN  HG UR SERA CH Bois Abbaye
#
#   PostalCode destination hospital CityName destination hospital  \
# 0                            None                          None
# 1                            None           Verviers (Verviers)
# 2                            None                Li√®ge (Glain)
# 3                            None                          None
# 4                            None             Seraing (Seraing)
#
#      StreetName destination hospital HouseNumber destination hospital  \
# 0                               None                             None
# 1                    Rue de la Marne                             None
# 2  Boulevard de Patience et Beaujonc                             None
# 3                               None                             None
# 4                        Rue Laplace                             None
#
#   Calculated travelTime destinatio  Calculated Distance destination  \
# 0                              NaN                              NaN
# 1                            461.0                           7398.0
# 2                            232.0                           3952.0
# 3                              NaN                              NaN
# 4                            227.0                           2794.0
#
#    Number of transported persons         Abandon reason
# 0                            NaN  Weigering van vervoer
# 1                            1.0                   None
# 2                            1.0                   None
# 3                            NaN   Verzorgd ter plaatse
# 4                            1.0                   None
#
# [5 rows x 46 columns]

# %%
# Concatenate vertically
intervention_data_23 = pd.concat([intervention_data_2, intervention_data_3])

# Reset index
intervention_data_23.reset_index(drop=True, inplace=True)

# %%
# filter the DataFrame using boolean indexing
filtered_interventions_23 = intervention_data_23[intervention_data_23['CityName intervention'].isin(leuven_submunicipalities)]

# %%
filtered_interventions_23
# Out:
# Empty DataFrame
# Columns: [Mission ID, Service Name, PostalCode permanence, CityName permanence, StreetName permanence, HouseNumber permanence, Latitude permanence, Longitude permanence, Permanence short name, Permanence long name, Vector type, EventType Firstcall, EventLevel Firstcall, EventType Trip, EventLevel Trip, PostalCode intervention, CityName intervention, Latitude intervention, Longitude intervention, Province intervention, T0, T1, T1confirmed, T2, T3, T4, T5, T6, T7, T9, Intervention time (T1Reported), Intervention time (T1Confirmed), Waiting time, Intervention duration, Departure time (T1Reported), Departure time (T1Confirmed), Unavailable time, Name destination hospital, PostalCode destination hospital, CityName destination hospital, StreetName destination hospital, HouseNumber destination hospital, Calculated travelTime destinatio, Calculated Distance destination, Number of transported persons, Abandon reason]
# Index: []
#
# [0 rows x 46 columns]

# %%
# create a list of Leuven and its submunicipalities
leuven_postalcodes = ['3000.0']

# filter the DataFrame using boolean indexing
test = intervention_data_23[intervention_data_23['PostalCode permanence'].isin(leuven_submunicipalities)]

# %%
test
# Out:
# Empty DataFrame
# Columns: [Mission ID, Service Name, PostalCode permanence, CityName permanence, StreetName permanence, HouseNumber permanence, Latitude permanence, Longitude permanence, Permanence short name, Permanence long name, Vector type, EventType Firstcall, EventLevel Firstcall, EventType Trip, EventLevel Trip, PostalCode intervention, CityName intervention, Latitude intervention, Longitude intervention, Province intervention, T0, T1, T1confirmed, T2, T3, T4, T5, T6, T7, T9, Intervention time (T1Reported), Intervention time (T1Confirmed), Waiting time, Intervention duration, Departure time (T1Reported), Departure time (T1Confirmed), Unavailable time, Name destination hospital, PostalCode destination hospital, CityName destination hospital, StreetName destination hospital, HouseNumber destination hospital, Calculated travelTime destinatio, Calculated Distance destination, Number of transported persons, Abandon reason]
# Index: []
#
# [0 rows x 46 columns]

# %% [markdown]
# these two did not contain any interventins in Leuven

# %%
# try for the cad9 dataset
cad_9 = pd.read_parquet("Data/cad9.parquet.gzip")

# %%
# print headings of data set
cad_9.head()
# Out:
#   province   Mission ID                 Service Name  Latitude permanence  \
# 0      VBR  21221520003             MV HVP VILV West            50.925277
# 1      VBR  21221520004             MV HVP HALL West            50.743200
# 2      VBR  21221520007             MV HVP VILV West            50.925277
# 3      VBR  21221520007   HV UR VILV AZ Jan Portaels            50.926869
# 4      VBR  21221520008  BB BRUX Hôpital Militair KA            50.905331
#
#    Longitude permanence Permanence short name Permanence long name  \
# 0              4.423057             AVVILV01A       ZW VILVOORDE 1
# 1              4.241053             AVHALL02A           ZW HALLE 2
# 2              4.423057             AVVILV01A       ZW VILVOORDE 1
# 3              4.420968             UVVILV01A        MUG VILVOORDE
# 4              4.387662             ABBRUX13A           AMB HMB 13
#
#   Vector Type                                  EventType Trip  \
# 0   Ambulance                            P034 - SCHEDELTRAUMA
# 1   Ambulance                 P010 - ADEMHALINGSMOEILIJKHEDEN
# 2   Ambulance  Y_TI BEVRIJDING PERSOON BEKLEMD/OPGESLOTEN+DGH
# 3         MUG  Y_TI BEVRIJDING PERSOON BEKLEMD/OPGESLOTEN+DGH
# 4   Ambulance                      P020 - INTOXICATIE ALCOHOL
#
#   EventSubType Trip  ...   Name destination hospital  \
# 0                 /  ...  HV UR VILV AZ JAN PORTAELS
# 1                 /  ...      HV UR HALL AZ ST MARIA
# 2                 /  ...  HV UR VILV AZ JAN PORTAELS
# 3                 /  ...  HV UR VILV AZ JAN PORTAELS
# 4                 /  ...                        None
#
#   Intervention time (T1Reported) Intervention time (T1Confirmed)  \
# 0                           10.0                             NaN
# 1                            7.0                             NaN
# 2                           10.0                             NaN
# 3                            7.0                             NaN
# 4                           14.0                             NaN
#
#    Departure time (T1Reported)  Departure time (T1Confirmed)  \
# 0                          2.0                           NaN
# 1                          3.0                           NaN
# 2                          4.0                           NaN
# 3                          1.0                           NaN
# 4                          7.0                           NaN
#
#                          UI        ID   MISSION_NR AMBUCODE    UNIT_ID
# 0  21221520003   1969661672  19189868  21221520003    240.0  MVVILV101
# 1  21221520004   1969661709  19189847  21221520004    240.0  MVHALL102
# 2  21221520007   1969664866  19190011  21221520007    240.0  MVVILV101
# 3  21221520007   1969665019  19190053  21221520007      0.0  MVVILV301
# 4  21221520008   1969665449  19189967  21221520008     39.0  MBMILH101
#
# [5 rows x 35 columns]

# %%
# inspect the dataset
print(cad_9.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289401 entries, 0 to 289400
# Data columns (total 35 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   province                         289401 non-null  object
#  1   Mission ID                       289401 non-null  int64
#  2   Service Name                     196821 non-null  object
#  3   Latitude permanence              233726 non-null  float64
#  4   Longitude permanence             233726 non-null  float64
#  5   Permanence short name            289204 non-null  object
#  6   Permanence long name             196821 non-null  object
#  7   Vector Type                      289401 non-null  object
#  8   EventType Trip                   289343 non-null  object
#  9   EventSubType Trip                289401 non-null  object
#  10  EventLevel Trip                  289331 non-null  object
#  11  CityName intervention            289277 non-null  object
#  12  CitysectionName intervention     285196 non-null  object
#  13  Latitude intervention            289400 non-null  float64
#  14  Longitude intervention           289400 non-null  float64
#  15  Province invervention            289303 non-null  object
#  16  T0                               285683 non-null  object
#  17  T1                               289401 non-null  object
#  18  T1confirmed                      113232 non-null  object
#  19  T2                               267224 non-null  object
#  20  T3                               263531 non-null  object
#  21  T4                               266211 non-null  object
#  22  T5                               226414 non-null  object
#  23  T6                               273778 non-null  object
#  24  T7                               57300 non-null   object
#  25  Name destination hospital        226414 non-null  object
#  26  Intervention time (T1Reported)   263531 non-null  float64
#  27  Intervention time (T1Confirmed)  110409 non-null  float64
#  28  Departure time (T1Reported)      267224 non-null  float64
#  29  Departure time (T1Confirmed)     111654 non-null  float64
#  30  UI                               289401 non-null  object
#  31  ID                               289401 non-null  int64
#  32  MISSION_NR                       289401 non-null  int64
#  33  AMBUCODE                         288721 non-null  float64
#  34  UNIT_ID                          289401 non-null  object
# dtypes: float64(9), int64(3), object(23)
# memory usage: 77.3+ MB
# None

# %%
# filter the DataFrame using boolean indexing
filtered_cad_9 = cad_9[cad_9['CityName intervention'].isin(leuven_submunicipalities)]

# %%
filtered_cad_9['CityName intervention']
# Out:
# 6        LEUVEN
# 9        LEUVEN
# 10       LEUVEN
# 11       LEUVEN
# 13       LEUVEN
#           ...
# 80023    LEUVEN
# 80026    LEUVEN
# 80053    LEUVEN
# 80058    LEUVEN
# 80063    LEUVEN
# Name: CityName intervention, Length: 9478, dtype: object

# %%
filtered_cad_9
# Out:
#       province   Mission ID                Service Name  Latitude permanence  \
# 6          VBR  21221520013        BV LEUV 112 Hageland            50.869703
# 9          VBR  21221520015  HV UR LEUV UZ Gasthuisberg            50.877462
# 10         VBR  21221520015   HV UR LEUV RZ Heilig Hart            50.872214
# 11         VBR  21221520017            MV HVP LEUV Oost            50.877589
# 13         VBR  21221520019            MV HVP LEUV Oost            50.877589
# ...        ...          ...                         ...                  ...
# 80023      VBR  21231510513  HV UR LEUV UZ Gasthuisberg            50.877462
# 80026      VBR  21231510521   HV UR LEUV RZ Heilig Hart            50.872214
# 80053      VBR  21231510591   HV UR LEUV RZ Heilig Hart            50.872214
# 80058      VBR  21231510607   HV UR LEUV RZ Heilig Hart            50.872214
# 80063      VBR  21231510613  HV UR LEUV UZ Gasthuisberg            50.877462
#
#        Longitude permanence Permanence short name Permanence long name  \
# 6                  4.723870             AVLEUV02A        ZW HEVERLEE 2
# 9                  4.674310             UVLEUV01A         MUG LEUVEN 1
# 10                 4.699613             AVLEUV01A       ZW LEUVEN 1 VK
# 11                 4.664523             AVLEUV03A          ZW LEUVEN 3
# 13                 4.664523             AVLEUV03A          ZW LEUVEN 3
# ...                     ...                   ...                  ...
# 80023              4.674310             PVLEUV01A         PIT LEUVEN 1
# 80026              4.699613             AVLEUV01A       ZW LEUVEN 1 VK
# 80053              4.699613             AVLEUV01A       ZW LEUVEN 1 VK
# 80058              4.699613             AVLEUV01A       ZW LEUVEN 1 VK
# 80063              4.674310             PVLEUV01A         PIT LEUVEN 1
#
#       Vector Type                                    EventType Trip  \
# 6       Ambulance  P039 - CARDIAAL PROBLEEM (NIET PIJN OP DE BORST)
# 9             MUG                     P016 - ZWANGERSCHAP-BEVALLING
# 10      Ambulance                     P016 - ZWANGERSCHAP-BEVALLING
# 11      Ambulance                       P068 - UROGENITAAL PROBLEEM
# 13      Ambulance                   P010 - ADEMHALINGSMOEILIJKHEDEN
# ...           ...                                               ...
# 80023         PIT                        P020 - INTOXICATIE ALCOHOL
# 80026   Ambulance         P026 - ONWEL/ZIEK ZONDER DUIDELIJKE FOCUS
# 80053   Ambulance        P075 - ONCOLOGISCHE PATIËNT IN BEHANDELING
# 80058   Ambulance                              P034 - SCHEDELTRAUMA
# 80063         PIT                                     P033 - TRAUMA
#
#       EventSubType Trip  ...   Name destination hospital  \
# 6                     /  ...   HV UR LEUV RZ HEILIG HART
# 9                     /  ...  HV UR LEUV UZ GASTHUISBERG
# 10                    /  ...  HV UR LEUV UZ GASTHUISBERG
# 11                    /  ...  HV UR LEUV UZ GASTHUISBERG
# 13                    /  ...  HV UR LEUV UZ GASTHUISBERG
# ...                 ...  ...                         ...
# 80023                 /  ...                        None
# 80026                 /  ...   HV UR LEUV RZ HEILIG HART
# 80053                 /  ...  HV UR LEUV UZ GASTHUISBERG
# 80058                 /  ...  HV UR LEUV UZ GASTHUISBERG
# 80063                 /  ...   HV UR LEUV RZ HEILIG HART
#
#       Intervention time (T1Reported) Intervention time (T1Confirmed)  \
# 6                               12.0                             NaN
# 9                                8.0                             NaN
# 10                               8.0                             NaN
# 11                              10.0                             NaN
# 13                              12.0                             NaN
# ...                              ...                             ...
# 80023                            NaN                             NaN
# 80026                            7.0                             NaN
# 80053                            6.0                             NaN
# 80058                            6.0                             NaN
# 80063                            9.0                             NaN
#
#        Departure time (T1Reported)  Departure time (T1Confirmed)  \
# 6                              2.0                           NaN
# 9                              3.0                           NaN
# 10                             3.0                           NaN
# 11                             3.0                           NaN
# 13                             3.0                           NaN
# ...                            ...                           ...
# 80023                          NaN                           NaN
# 80026                          2.0                           NaN
# 80053                          1.0                           NaN
# 80058                          2.0                           NaN
# 80063                          3.0                           NaN
#
#                              UI        ID   MISSION_NR AMBUCODE    UNIT_ID
# 6      21221520013   1969669643  19190103  21221520013    254.0  MVLEUV102
# 9      21221520015   1969670377  19190090  21221520015      0.0  MVLEUV301
# 10     21221520015   1969670378  19190120  21221520015    263.0  MVLEVK101
# 11     21221520017   1969671559  19190138  21221520017    230.0  MVLEUV103
# 13     21221520019   1969676602  19190271  21221520019    230.0  MVLEUV103
# ...                         ...       ...          ...      ...        ...
# 80023  21231510513   2001177624  21355595  21231510513    288.0  MVLEUV201
# 80026  21231510521   2001178178  21355553  21231510521    263.0  MVLEVK101
# 80053  21231510591   2001184686  21356069  21231510591    263.0  MVLEVK101
# 80058  21231510607   2001188812  21356381  21231510607    263.0  MVLEVK101
# 80063  21231510613   2001189601  21356474  21231510613    288.0  MVLEUV201
#
# [9478 rows x 35 columns]

# %%
# make csv just to see what cardiac arrest is written as 
# Specify the file path where you want to save the CSV file
file_path = "cardiac.csv"

# Save the dataframe to a CSV file
filtered_cad_9.to_csv(file_path, index=False)

# If you want to include the index in the CSV file, remove index=False
# df.to_csv(file_path)

print("DataFrame saved to CSV successfully!")
# Out:
# DataFrame saved to CSV successfully!

# %%
# filter on type of intervention
cardiac_arrest = ['P003 - HARTSTILSTAND - DOOD - OVERLEDEN']
cad_9_cardiac = filtered_cad_9[filtered_cad_9['EventType Trip'].isin(cardiac_arrest)]

# %%
cad_9_cardiac
# Out:
#       province   Mission ID                Service Name  Latitude permanence  \
# 708        VBR  21221540548   HV UR LEUV RZ Heilig Hart            50.872214
# 1214       VBR  21221580059        BV LEUV 112 Hageland            50.869703
# 1215       VBR  21221580059  HV UR LEUV UZ Gasthuisberg            50.877462
# 1484       VBR  21221590150  HV UR LEUV UZ Gasthuisberg            50.877462
# 1485       VBR  21221590150        BV LEUV 112 Hageland            50.869703
# ...        ...          ...                         ...                  ...
# 73854      VBR  21231230397            MV HVP LEUV Oost            50.877589
# 73855      VBR  21231230397  HV UR LEUV UZ Gasthuisberg            50.877462
# 75885      VBR  21231330264  HV UR LEUV UZ Gasthuisberg            50.877462
# 75886      VBR  21231330264            MV HVP LEUV Oost            50.877589
# 76045      VBR  21231330871  HV UR LEUV UZ Gasthuisberg            50.877462
#
#        Longitude permanence Permanence short name Permanence long name  \
# 708                4.699613             AVLEUV01A       ZW LEUVEN 1 VK
# 1214               4.723870             AVLEUV02A        ZW HEVERLEE 2
# 1215               4.674310             UVLEUV01A         MUG LEUVEN 1
# 1484               4.674310             UVLEUV01A         MUG LEUVEN 1
# 1485               4.723870             AVLEUV02A        ZW HEVERLEE 2
# ...                     ...                   ...                  ...
# 73854              4.664523             AVLEUV04A          ZW LEUVEN 4
# 73855              4.674310             UVLEUV02A         MUG LEUVEN 2
# 75885              4.674310             UVLEUV02A         MUG LEUVEN 2
# 75886              4.664523             AVLEUV04A          ZW LEUVEN 4
# 76045              4.674310             UVLEUV01A         MUG LEUVEN 1
#
#       Vector Type                           EventType Trip EventSubType Trip  \
# 708     Ambulance  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 1214    Ambulance  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 1215          MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 1484          MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 1485    Ambulance  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# ...           ...                                      ...               ...
# 73854   Ambulance  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 73855         MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 75885         MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 75886   Ambulance  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 76045         MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
#
#        ...   Name destination hospital Intervention time (T1Reported)  \
# 708    ...                        None                            NaN
# 1214   ...  HV UR LEUV UZ GASTHUISBERG                            9.0
# 1215   ...  HV UR LEUV UZ GASTHUISBERG                            9.0
# 1484   ...                        None                            9.0
# 1485   ...                        None                            9.0
# ...    ...                         ...                            ...
# 73854  ...  HV UR LEUV UZ GASTHUISBERG                            8.0
# 73855  ...  HV UR LEUV UZ GASTHUISBERG                            6.0
# 75885  ...                        None                           24.0
# 75886  ...                        None                           24.0
# 76045  ...                        None                            9.0
#
#       Intervention time (T1Confirmed)  Departure time (T1Reported)  \
# 708                               NaN                          NaN
# 1214                              NaN                          3.0
# 1215                              NaN                          3.0
# 1484                              NaN                          3.0
# 1485                              NaN                          3.0
# ...                               ...                          ...
# 73854                             NaN                          3.0
# 73855                             NaN                          1.0
# 75885                            20.0                          4.0
# 75886                            20.0                          4.0
# 76045                             NaN                          3.0
#
#        Departure time (T1Confirmed)                        UI        ID  \
# 708                             NaN  21221540548   1969915734  19207090
# 1214                            NaN  21221580059   1970204537  19225969
# 1215                            NaN  21221580059   1970204549  19225922
# 1484                            NaN  21221590150   1970313994  19233510
# 1485                            NaN  21221590150   1970313996  19233508
# ...                             ...                       ...       ...
# 73854                           NaN  21231230397   1998754726  21186385
# 73855                           NaN  21231230397   1998754841  21186404
# 75885                           0.0  21231330264   1999596413  21243526
# 75886                           0.0  21231330264   1999596414  21243497
# 76045                           NaN  21231330871   1999639723  21247858
#
#         MISSION_NR AMBUCODE    UNIT_ID
# 708    21221540548    263.0  MVLEVK101
# 1214   21221580059    254.0  MVLEUV102
# 1215   21221580059      0.0  MVLEUV301
# 1484   21221590150      0.0  MVLEUV301
# 1485   21221590150    254.0  MVLEUV102
# ...            ...      ...        ...
# 73854  21231230397    230.0  MVLEUV104
# 73855  21231230397      0.0  UVLEUV02A
# 75885  21231330264      0.0  UVLEUV02A
# 75886  21231330264    230.0  MVLEUV104
# 76045  21231330871      0.0  UVLEUV01A
#
# [165 rows x 35 columns]

# %%
cad_9_cardiac['T1']
# Out:
# 708      03JUN22:22:48:54
# 1214     07JUN22:07:02:17
# 1215     07JUN22:07:02:29
# 1484     08JUN22:13:26:34
# 1485     08JUN22:13:26:36
#                ...
# 73854    03MAY23:17:38:46
# 73855    03MAY23:17:40:41
# 75885    13MAY23:11:26:53
# 75886    13MAY23:11:26:54
# 76045    13MAY23:23:28:43
# Name: T1, Length: 165, dtype: object

# %%
cad_9_cardiac['T3']
# Out:
# 708                         None
# 1214     2022-06-07 07:11:24.000
# 1215     2022-06-07 07:11:24.000
# 1484     2022-06-08 13:35:03.000
# 1485     2022-06-08 13:35:03.000
#                   ...
# 73854    2023-05-03 17:46:05.000
# 73855    2023-05-03 17:46:05.000
# 75885    2023-05-13 11:50:12.000
# 75886    2023-05-13 11:50:12.000
# 76045    2023-05-13 23:37:00.000
# Name: T3, Length: 165, dtype: object

# %%
# drop rows with None values
# Remove rows with 'None' values only from specific columns
cad_9_cardiac.dropna(subset=['T1', 'T3'], inplace=True)
# Out:
# C:\Users\leonw\AppData\Local\Temp\ipykernel_29420\3342357423.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cad_9_cardiac.dropna(subset=['T1', 'T3'], inplace=True)

# %%
cad_9_cardiac
# Out:
#       province   Mission ID                Service Name  Latitude permanence  \
# 1214       VBR  21221580059        BV LEUV 112 Hageland            50.869703
# 1215       VBR  21221580059  HV UR LEUV UZ Gasthuisberg            50.877462
# 1484       VBR  21221590150  HV UR LEUV UZ Gasthuisberg            50.877462
# 1485       VBR  21221590150        BV LEUV 112 Hageland            50.869703
# 1500       VBR  21221590196  HV UR LEUV UZ Gasthuisberg            50.877462
# ...        ...          ...                         ...                  ...
# 73854      VBR  21231230397            MV HVP LEUV Oost            50.877589
# 73855      VBR  21231230397  HV UR LEUV UZ Gasthuisberg            50.877462
# 75885      VBR  21231330264  HV UR LEUV UZ Gasthuisberg            50.877462
# 75886      VBR  21231330264            MV HVP LEUV Oost            50.877589
# 76045      VBR  21231330871  HV UR LEUV UZ Gasthuisberg            50.877462
#
#        Longitude permanence Permanence short name Permanence long name  \
# 1214               4.723870             AVLEUV02A        ZW HEVERLEE 2
# 1215               4.674310             UVLEUV01A         MUG LEUVEN 1
# 1484               4.674310             UVLEUV01A         MUG LEUVEN 1
# 1485               4.723870             AVLEUV02A        ZW HEVERLEE 2
# 1500               4.674310             UVLEUV01A         MUG LEUVEN 1
# ...                     ...                   ...                  ...
# 73854              4.664523             AVLEUV04A          ZW LEUVEN 4
# 73855              4.674310             UVLEUV02A         MUG LEUVEN 2
# 75885              4.674310             UVLEUV02A         MUG LEUVEN 2
# 75886              4.664523             AVLEUV04A          ZW LEUVEN 4
# 76045              4.674310             UVLEUV01A         MUG LEUVEN 1
#
#       Vector Type                           EventType Trip EventSubType Trip  \
# 1214    Ambulance  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 1215          MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 1484          MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 1485    Ambulance  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 1500          MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# ...           ...                                      ...               ...
# 73854   Ambulance  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 73855         MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 75885         MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 75886   Ambulance  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 76045         MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
#
#        ...   Name destination hospital Intervention time (T1Reported)  \
# 1214   ...  HV UR LEUV UZ GASTHUISBERG                            9.0
# 1215   ...  HV UR LEUV UZ GASTHUISBERG                            9.0
# 1484   ...                        None                            9.0
# 1485   ...                        None                            9.0
# 1500   ...                        None                           12.0
# ...    ...                         ...                            ...
# 73854  ...  HV UR LEUV UZ GASTHUISBERG                            8.0
# 73855  ...  HV UR LEUV UZ GASTHUISBERG                            6.0
# 75885  ...                        None                           24.0
# 75886  ...                        None                           24.0
# 76045  ...                        None                            9.0
#
#       Intervention time (T1Confirmed)  Departure time (T1Reported)  \
# 1214                              NaN                          3.0
# 1215                              NaN                          3.0
# 1484                              NaN                          3.0
# 1485                              NaN                          3.0
# 1500                              NaN                          5.0
# ...                               ...                          ...
# 73854                             NaN                          3.0
# 73855                             NaN                          1.0
# 75885                            20.0                          4.0
# 75886                            20.0                          4.0
# 76045                             NaN                          3.0
#
#        Departure time (T1Confirmed)                        UI        ID  \
# 1214                            NaN  21221580059   1970204537  19225969
# 1215                            NaN  21221580059   1970204549  19225922
# 1484                            NaN  21221590150   1970313994  19233510
# 1485                            NaN  21221590150   1970313996  19233508
# 1500                            NaN  21221590196   1970318119  19233963
# ...                             ...                       ...       ...
# 73854                           NaN  21231230397   1998754726  21186385
# 73855                           NaN  21231230397   1998754841  21186404
# 75885                           0.0  21231330264   1999596413  21243526
# 75886                           0.0  21231330264   1999596414  21243497
# 76045                           NaN  21231330871   1999639723  21247858
#
#         MISSION_NR AMBUCODE    UNIT_ID
# 1214   21221580059    254.0  MVLEUV102
# 1215   21221580059      0.0  MVLEUV301
# 1484   21221590150      0.0  MVLEUV301
# 1485   21221590150    254.0  MVLEUV102
# 1500   21221590196      0.0  MVLEUV301
# ...            ...      ...        ...
# 73854  21231230397    230.0  MVLEUV104
# 73855  21231230397      0.0  UVLEUV02A
# 75885  21231330264      0.0  UVLEUV02A
# 75886  21231330264    230.0  MVLEUV104
# 76045  21231330871      0.0  UVLEUV01A
#
# [146 rows x 35 columns]

# %%
# can only use the ones that have T1, T3, longitude and latitude filer out the rest 
filtered_cad_9_cardiac = cad_9_cardiac[cad_9_cardiac['T1'].notna()]
filtered_cad_9_cardiac = cad_9_cardiac[cad_9_cardiac['T3'].notna()]
filtered_cad_9_cardiac = cad_9_cardiac[cad_9_cardiac['Longitude intervention'].notna()]
filtered_cad_9_cardiac = cad_9_cardiac[cad_9_cardiac['Latitude intervention'].notna()]
filtered_cad_9_cardiac
# Out:
#       province   Mission ID                Service Name  Latitude permanence  \
# 1214       VBR  21221580059        BV LEUV 112 Hageland            50.869703
# 1215       VBR  21221580059  HV UR LEUV UZ Gasthuisberg            50.877462
# 1484       VBR  21221590150  HV UR LEUV UZ Gasthuisberg            50.877462
# 1485       VBR  21221590150        BV LEUV 112 Hageland            50.869703
# 1500       VBR  21221590196  HV UR LEUV UZ Gasthuisberg            50.877462
# ...        ...          ...                         ...                  ...
# 73854      VBR  21231230397            MV HVP LEUV Oost            50.877589
# 73855      VBR  21231230397  HV UR LEUV UZ Gasthuisberg            50.877462
# 75885      VBR  21231330264  HV UR LEUV UZ Gasthuisberg            50.877462
# 75886      VBR  21231330264            MV HVP LEUV Oost            50.877589
# 76045      VBR  21231330871  HV UR LEUV UZ Gasthuisberg            50.877462
#
#        Longitude permanence Permanence short name Permanence long name  \
# 1214               4.723870             AVLEUV02A        ZW HEVERLEE 2
# 1215               4.674310             UVLEUV01A         MUG LEUVEN 1
# 1484               4.674310             UVLEUV01A         MUG LEUVEN 1
# 1485               4.723870             AVLEUV02A        ZW HEVERLEE 2
# 1500               4.674310             UVLEUV01A         MUG LEUVEN 1
# ...                     ...                   ...                  ...
# 73854              4.664523             AVLEUV04A          ZW LEUVEN 4
# 73855              4.674310             UVLEUV02A         MUG LEUVEN 2
# 75885              4.674310             UVLEUV02A         MUG LEUVEN 2
# 75886              4.664523             AVLEUV04A          ZW LEUVEN 4
# 76045              4.674310             UVLEUV01A         MUG LEUVEN 1
#
#       Vector Type                           EventType Trip EventSubType Trip  \
# 1214    Ambulance  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 1215          MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 1484          MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 1485    Ambulance  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 1500          MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# ...           ...                                      ...               ...
# 73854   Ambulance  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 73855         MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 75885         MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 75886   Ambulance  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
# 76045         MUG  P003 - HARTSTILSTAND - DOOD - OVERLEDEN                 /
#
#        ...   Name destination hospital Intervention time (T1Reported)  \
# 1214   ...  HV UR LEUV UZ GASTHUISBERG                            9.0
# 1215   ...  HV UR LEUV UZ GASTHUISBERG                            9.0
# 1484   ...                        None                            9.0
# 1485   ...                        None                            9.0
# 1500   ...                        None                           12.0
# ...    ...                         ...                            ...
# 73854  ...  HV UR LEUV UZ GASTHUISBERG                            8.0
# 73855  ...  HV UR LEUV UZ GASTHUISBERG                            6.0
# 75885  ...                        None                           24.0
# 75886  ...                        None                           24.0
# 76045  ...                        None                            9.0
#
#       Intervention time (T1Confirmed)  Departure time (T1Reported)  \
# 1214                              NaN                          3.0
# 1215                              NaN                          3.0
# 1484                              NaN                          3.0
# 1485                              NaN                          3.0
# 1500                              NaN                          5.0
# ...                               ...                          ...
# 73854                             NaN                          3.0
# 73855                             NaN                          1.0
# 75885                            20.0                          4.0
# 75886                            20.0                          4.0
# 76045                             NaN                          3.0
#
#        Departure time (T1Confirmed)                        UI        ID  \
# 1214                            NaN  21221580059   1970204537  19225969
# 1215                            NaN  21221580059   1970204549  19225922
# 1484                            NaN  21221590150   1970313994  19233510
# 1485                            NaN  21221590150   1970313996  19233508
# 1500                            NaN  21221590196   1970318119  19233963
# ...                             ...                       ...       ...
# 73854                           NaN  21231230397   1998754726  21186385
# 73855                           NaN  21231230397   1998754841  21186404
# 75885                           0.0  21231330264   1999596413  21243526
# 75886                           0.0  21231330264   1999596414  21243497
# 76045                           NaN  21231330871   1999639723  21247858
#
#         MISSION_NR AMBUCODE    UNIT_ID
# 1214   21221580059    254.0  MVLEUV102
# 1215   21221580059      0.0  MVLEUV301
# 1484   21221590150      0.0  MVLEUV301
# 1485   21221590150    254.0  MVLEUV102
# 1500   21221590196      0.0  MVLEUV301
# ...            ...      ...        ...
# 73854  21231230397    230.0  MVLEUV104
# 73855  21231230397      0.0  UVLEUV02A
# 75885  21231330264      0.0  UVLEUV02A
# 75886  21231330264    230.0  MVLEUV104
# 76045  21231330871      0.0  UVLEUV01A
#
# [146 rows x 35 columns]

# %%
# filter data, want to save T2, T3, latitude + longitude 
final_interventions = filtered_cad_9_cardiac[['T1', 'T3', 'Latitude intervention', 'Longitude intervention']]

# %%
final_interventions
# Out:
#                      T1                       T3  Latitude intervention  \
# 1214   07JUN22:07:02:17  2022-06-07 07:11:24.000              50.861866
# 1215   07JUN22:07:02:29  2022-06-07 07:11:24.000              50.861866
# 1484   08JUN22:13:26:34  2022-06-08 13:35:03.000              50.873174
# 1485   08JUN22:13:26:36  2022-06-08 13:35:03.000              50.873174
# 1500   08JUN22:14:35:19  2022-06-08 14:47:58.000              50.928140
# ...                 ...                      ...                    ...
# 73854  03MAY23:17:38:46  2023-05-03 17:46:05.000              50.861650
# 73855  03MAY23:17:40:41  2023-05-03 17:46:05.000              50.861650
# 75885  13MAY23:11:26:53  2023-05-13 11:50:12.000              50.885531
# 75886  13MAY23:11:26:54  2023-05-13 11:50:12.000              50.885531
# 76045  13MAY23:23:28:43  2023-05-13 23:37:00.000              50.856026
#
#        Longitude intervention
# 1214                 4.708210
# 1215                 4.708210
# 1484                 4.716699
# 1485                 4.716699
# 1500                 4.703247
# ...                       ...
# 73854                4.681370
# 73855                4.681370
# 75885                4.684591
# 75886                4.684591
# 76045                4.695739
#
# [146 rows x 4 columns]

# %%
# reset index 
final_interventions = final_interventions.reset_index(drop=True)
final_interventions
# Out:
#                    T1                       T3  Latitude intervention  \
# 0    07JUN22:07:02:17  2022-06-07 07:11:24.000              50.861866
# 1    07JUN22:07:02:29  2022-06-07 07:11:24.000              50.861866
# 2    08JUN22:13:26:34  2022-06-08 13:35:03.000              50.873174
# 3    08JUN22:13:26:36  2022-06-08 13:35:03.000              50.873174
# 4    08JUN22:14:35:19  2022-06-08 14:47:58.000              50.928140
# ..                ...                      ...                    ...
# 141  03MAY23:17:38:46  2023-05-03 17:46:05.000              50.861650
# 142  03MAY23:17:40:41  2023-05-03 17:46:05.000              50.861650
# 143  13MAY23:11:26:53  2023-05-13 11:50:12.000              50.885531
# 144  13MAY23:11:26:54  2023-05-13 11:50:12.000              50.885531
# 145  13MAY23:23:28:43  2023-05-13 23:37:00.000              50.856026
#
#      Longitude intervention
# 0                  4.708210
# 1                  4.708210
# 2                  4.716699
# 3                  4.716699
# 4                  4.703247
# ..                      ...
# 141                4.681370
# 142                4.681370
# 143                4.684591
# 144                4.684591
# 145                4.695739
#
# [146 rows x 4 columns]

# %%
# make a column for dif between T2 and T3

# calculate the delivertime 
# Convert date columns to datetime objects
final_interventions ['T1'] = pd.to_datetime(final_interventions ['T1'], format='%d%b%y:%H:%M:%S')
final_interventions ['T3'] = pd.to_datetime(final_interventions ['T3'])

# Calculate delivery time
final_interventions['Response Time'] = (final_interventions ['T3'] - final_interventions ['T1']).dt.total_seconds()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 5
#       1 # make a column for dif between T2 and T3
#       2
#       3 # calculate the delivertime
#       4 # Convert date columns to datetime objects
# ----> 5 final_interventions ['T1'] = pd.to_datetime(final_interventions ['T1'], format='%d%b%y:%H:%M:%S')
#       6 final_interventions ['T3'] = pd.to_datetime(final_interventions ['T3'])
#       8 # Calculate delivery time
#
# File c:\Users\leonw\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1112, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1110         result = arg.map(cache_array)
#    1111     else:
# -> 1112         values = convert_listlike(arg._values, format)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\leonw\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:488, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     486 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     487 if format is not None and format != "mixed":
# --> 488     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     490 result, tz_parsed = objects_to_datetime64ns(
#     491     arg,
#     492     dayfirst=dayfirst,
#    (...)
#     496     allow_object=True,
#     497 )
#     499 if tz_parsed is not None:
#     500     # We can take a shortcut since the datetime64 numpy array
#     501     # is in UTC
#
# File c:\Users\leonw\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:519, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     508 def _array_strptime_with_fallback(
#     509     arg,
#     510     name,
#    (...)
#     514     errors: str,
#     515 ) -> Index:
#     516     """
#     517     Call array_strptime, with fallback behavior depending on 'errors'.
#     518     """
# --> 519     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     520     if any(tz is not None for tz in timezones):
#     521         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File strptime.pyx:534, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:355, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "04OCT22:18:13:01" doesn't match format "%d%b%y:%H:%M:%S", at position 47. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
final_interventions
# Out:
#                      T1                  T3  Latitude intervention  \
# 0   2022-06-07 07:02:17 2022-06-07 07:11:24              50.861866
# 1   2022-06-07 07:02:29 2022-06-07 07:11:24              50.861866
# 2   2022-06-08 13:26:34 2022-06-08 13:35:03              50.873174
# 3   2022-06-08 13:26:36 2022-06-08 13:35:03              50.873174
# 4   2022-06-08 14:35:19 2022-06-08 14:47:58              50.928140
# ..                  ...                 ...                    ...
# 141 2023-05-03 17:38:46 2023-05-03 17:46:05              50.861650
# 142 2023-05-03 17:40:41 2023-05-03 17:46:05              50.861650
# 143 2023-05-13 11:26:53 2023-05-13 11:50:12              50.885531
# 144 2023-05-13 11:26:54 2023-05-13 11:50:12              50.885531
# 145 2023-05-13 23:28:43 2023-05-13 23:37:00              50.856026
#
#      Longitude intervention  Response Time
# 0                  4.708210          547.0
# 1                  4.708210          535.0
# 2                  4.716699          509.0
# 3                  4.716699          507.0
# 4                  4.703247          759.0
# ..                      ...            ...
# 141                4.681370          439.0
# 142                4.681370          324.0
# 143                4.684591         1399.0
# 144                4.684591         1398.0
# 145                4.695739          497.0
#
# [146 rows x 5 columns]

# %%
# there are some interventions that appear twice, same patient spot and T3 but different T1, probably sveral calls for same incidence
# remove these by removing rows that have exactly the same latitude + longitude + T3 and keep the first one 
# the first one is the first call
# Drop duplicates based on 'T3', 'Longitude intervention', and 'Latitude intervention' columns
final_interventions = final_interventions.drop_duplicates(subset=['T3', 'Longitude intervention', 'Latitude intervention'])

# %%
final_interventions
# Out:
#                    T1                       T3  Latitude intervention  \
# 0    07JUN22:07:02:17  2022-06-07 07:11:24.000              50.861866
# 1    07JUN22:07:02:29  2022-06-07 07:11:24.000              50.861866
# 2    08JUN22:13:26:34  2022-06-08 13:35:03.000              50.873174
# 3    08JUN22:13:26:36  2022-06-08 13:35:03.000              50.873174
# 4    08JUN22:14:35:19  2022-06-08 14:47:58.000              50.928140
# ..                ...                      ...                    ...
# 141  03MAY23:17:38:46  2023-05-03 17:46:05.000              50.861650
# 142  03MAY23:17:40:41  2023-05-03 17:46:05.000              50.861650
# 143  13MAY23:11:26:53  2023-05-13 11:50:12.000              50.885531
# 144  13MAY23:11:26:54  2023-05-13 11:50:12.000              50.885531
# 145  13MAY23:23:28:43  2023-05-13 23:37:00.000              50.856026
#
#      Longitude intervention
# 0                  4.708210
# 1                  4.708210
# 2                  4.716699
# 3                  4.716699
# 4                  4.703247
# ..                      ...
# 141                4.681370
# 142                4.681370
# 143                4.684591
# 144                4.684591
# 145                4.695739
#
# [146 rows x 4 columns]

# %%
# reset index 
final_interventions = final_interventions.reset_index(drop=True)
final_interventions
# Out:
#                    T1                       T3  Latitude intervention  \
# 0    07JUN22:07:02:17  2022-06-07 07:11:24.000              50.861866
# 1    07JUN22:07:02:29  2022-06-07 07:11:24.000              50.861866
# 2    08JUN22:13:26:34  2022-06-08 13:35:03.000              50.873174
# 3    08JUN22:13:26:36  2022-06-08 13:35:03.000              50.873174
# 4    08JUN22:14:35:19  2022-06-08 14:47:58.000              50.928140
# ..                ...                      ...                    ...
# 141  03MAY23:17:38:46  2023-05-03 17:46:05.000              50.861650
# 142  03MAY23:17:40:41  2023-05-03 17:46:05.000              50.861650
# 143  13MAY23:11:26:53  2023-05-13 11:50:12.000              50.885531
# 144  13MAY23:11:26:54  2023-05-13 11:50:12.000              50.885531
# 145  13MAY23:23:28:43  2023-05-13 23:37:00.000              50.856026
#
#      Longitude intervention
# 0                  4.708210
# 1                  4.708210
# 2                  4.716699
# 3                  4.716699
# 4                  4.703247
# ..                      ...
# 141                4.681370
# 142                4.681370
# 143                4.684591
# 144                4.684591
# 145                4.695739
#
# [146 rows x 4 columns]

# %%
# save the intervantions dataset 

file_path = "Data/interventions.csv"

# Save the dataframe to a CSV file
final_interventions.to_csv(file_path, index=False)

# If you want to include the index in the CSV file, remove index=False
# df.to_csv(file_path)

print("DataFrame saved to CSV successfully!")
# Out:
# DataFrame saved to CSV successfully!
